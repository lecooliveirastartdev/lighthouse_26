# %%
nome = "Lira Maria"
carro = "Fusca"
tamanho = len(nome)
print("L" in "Lira")
print(type(nome))
print(len(nome)) 
soma =  2 + 2
print(soma)
# Out:
# True
# <class 'str'>
# 10
# 4

# %%
soma =  2 + 2
